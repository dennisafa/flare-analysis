# %%
import wolf359.wolfapp as wolf
from lightkurve import KeplerTargetPixelFile
w359 = KeplerTargetPixelFile.from_archive(201885041, cadence='short')
lc359 = w359.to_lightcurve(aperture_mask=w359.pipeline_mask)
# Out:
# Found 1 File(s)
# ...
#  [Failed]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-acf707d963c9> in <module>()
#       1 import wolf359.wolfapp as wolf
#       2 from lightkurve import KeplerTargetPixelFile
# ----> 3 w359 = KeplerTargetPixelFile.from_archive(201885041, cadence='short')
#       4 lc359 = w359.to_lightcurve(aperture_mask=w359.pipeline_mask)
#
# /anaconda/envs/flares/lib/python3.6/site-packages/lightkurve/targetpixelfile.py in from_archive(target, cadence, quarter, month, campaign, radius, targetlimit, verbose, **kwargs)
#     179                     target=target, filetype='Target Pixel', cadence=cadence,
#     180                     quarter=quarter, campaign=campaign, month=month, verbose=verbose,
# --> 181                     radius=radius, targetlimit=targetlimit)
#     182         if len(path) == 1:
# ...

# %%
wolf.call(lc359, lc359.flux)
# Out:
# Flare detect successful, number of flares: 3 at slice number 0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-010379291d85> in <module>()
# ----> 1 wolf.call(lc359, lc359.flux)
#
# ~/Desktop/flares/wolf359/wolfapp.py in call(lc359, fluxwolf)
#     111         flare = strPlot(lc359, slice, slice + steps)
#     112         georgemodel = flare.computegeorge()
# --> 113         guessparams = flare.guesspeaks(track)
#     114         bounds = flare.setbounds(guessparams)
#     115         notempty = checkzero(flare.detflares)
#
# ~/Desktop/flares/wolf359/wolfapp.py in guesspeaks(self, sliceNum)
#      63         for i, flareVal in enumerate(self.detflares):
#      64             self.flarepeak = flareVal
# ---> 65             self.flaretime = self.findflaretime(self.flarepeak, self.flux, self.time)
# ...
